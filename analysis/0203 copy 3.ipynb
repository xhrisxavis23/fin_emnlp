# %%
from pathlib import Path
import json
import pandas as pd

RUNS_ROOT = Path("/home/dgu/fin/01_15_new_qlib/runs")
files = sorted(RUNS_ROOT.glob("*/specs/stage4_summary.json"))
print("found:", len(files))
# Out:
# found: 146

# %%
from pathlib import Path
import json
import pandas as pd

RUNS_ROOT = Path("/home/dgu/fin/01_15_new_qlib/runs")
files = sorted(RUNS_ROOT.glob("*/specs/stage4_summary.json"))
print("found:", len(files))

def load_run_qlib_meta(run_dir: Path) -> dict:
    """runs/<run_id>/run_config.json 에서 universe(us/cn) 메타를 읽는다."""
    cfg_path = run_dir / "run_config.json"
    if not cfg_path.exists():
        return {}
    try:
        with open(cfg_path, "r", encoding="utf-8") as f:
            cfg = json.load(f)
        qlib_cfg = ((cfg or {}).get("config", {}) or {}).get("qlib", {}) or {}
        pipeline_cfg = ((cfg or {}).get("config", {}) or {}).get("pipeline_control", {}) or {}
        region = qlib_cfg.get("region")
        return {
            "universe": region,  # "cn" / "us"
            "region": region,
            "qlib_market": qlib_cfg.get("qlib_market"),
            "provider_uri": qlib_cfg.get("provider_uri"),
            "benchmark_code": qlib_cfg.get("benchmark"),
            "enable_stage2": pipeline_cfg.get("enable_stage2"),
            "enable_stage3": pipeline_cfg.get("enable_stage3"),
        }
    except Exception as e:
        print("warn: failed to read run_config:", cfg_path, e)
        return {}

def iter_outer_roots(j: dict):
    """
    stage4_summary 최상단이 {"outer_iter_1": {...}, "outer_iter_2": {...}} 처럼
    여러 outer_iter가 있을 수 있어서 모두 yield.
    단일 dict만 있는 경우에도 대응.
    """
    if not isinstance(j, dict):
        return
    # outer_iter_* 키가 있으면 그걸 전부
    outer_keys = [k for k in j.keys() if isinstance(k, str) and k.startswith("outer_iter_")]
    if outer_keys:
        for k in sorted(outer_keys):
            if isinstance(j.get(k), dict):
                yield k, j[k]
    else:
        # 그냥 root dict인 경우
        yield "root", j

rows = []

for p in files:
    run_dir = p.parents[1]  # runs/<run_id>/specs/stage4_summary.json
    run_id = run_dir.name
    run_meta = load_run_qlib_meta(run_dir)
    try:
        with open(p, "r", encoding="utf-8") as f:
            j = json.load(f)

        for outer_key, root in iter_outer_roots(j):
            base = {
                "run_id": run_id,
                "outer_iter": outer_key,
                **run_meta,
                "hypothesis_id": root.get("hypothesis_id"),
                "backtest_mode": root.get("backtest_mode"),
                "horizon_days": root.get("horizon_days"),
                "in_sample_period": root.get("in_sample_period"),
                "out_sample_period": root.get("out_sample_period"),
            }

            for combo in root.get("all_combinations", []) or []:
                combo_idx = combo.get("combo_idx")

                # (A) optuna 결과 = combo.outsample.excess_return_with_cost
                ex_optuna = (combo.get("outsample", {}) or {}).get("excess_return_with_cost", None)
                rows.append({
                    **base,
                    "combo_idx": combo_idx,
                    "mode": "optuna",
                    "threshold_q": None,  # fixed만 존재
                    "optimal_thresholds": combo.get("optimal_thresholds", None),  # optuna에서 의미있음(있으면)
                    "outsample_excess_return_with_cost": ex_optuna,  # dict 그대로
                })

                # (B) fixed 결과 = combo.fixed_modes[fixed_qXX].outsample.excess_return_with_cost
                fixed_modes = combo.get("fixed_modes", {}) or {}
                for mode_name, mode_data in fixed_modes.items():
                    ex_fixed = (mode_data.get("outsample", {}) or {}).get("excess_return_with_cost", None)
                    rows.append({
                        **base,
                        "combo_idx": combo_idx,
                        "mode": mode_name,  # fixed_q90, fixed_q95 등
                        "threshold_q": mode_data.get("threshold_q", None),
                        "optimal_thresholds": None,  # fixed에는 보통 없음
                        "outsample_excess_return_with_cost": ex_fixed,  # dict 그대로
                    })

    except Exception as e:
        print("fail:", p, e)

df_raw = pd.DataFrame(rows)
df_raw.head()
# Out:
# found: 146
#             run_id outer_iter             hypothesis_id backtest_mode  \
# 0  20260122_100355       root  BH_MR_PanicSelling_3D_v1          qlib
# 1  20260122_100355       root  BH_MR_PanicSelling_3D_v1          qlib
# 2  20260122_100355       root  BH_MR_PanicSelling_3D_v1          qlib
# 3  20260122_100355       root  BH_MR_PanicSelling_3D_v1          qlib
# 4  20260122_100355       root  BH_MR_PanicSelling_3D_v1          qlib
#
#    horizon_days         in_sample_period        out_sample_period combo_idx  \
# 0           3.0  2023-01-01 ~ 2024-12-31  2025-01-01 ~ 2025-12-31         1
# 1           3.0  2023-01-01 ~ 2024-12-31  2025-01-01 ~ 2025-12-31         2
# 2           3.0  2023-01-01 ~ 2024-12-31  2025-01-01 ~ 2025-12-31         3
# 3           3.0  2023-01-01 ~ 2024-12-31  2025-01-01 ~ 2025-12-31         4
# 4           3.0  2023-01-01 ~ 2024-12-31  2025-01-01 ~ 2025-12-31         5
#
#      mode  threshold_q                                 optimal_thresholds  \
# 0  optuna          NaN  {'volume_surge_zscore': 0.71866277978636, 'liq...
# 1  optuna          NaN  {'volume_surge_zscore': 0.8614988717085303, 'l...
# 2  optuna          NaN  {'volume_surge_zscore': 0.6531239780871886, 'l...
# 3  optuna          NaN  {'volume_surge_zscore': 0.7673745974615892, 'l...
# 4  optuna          NaN  {'volume_surge_zscore': 0.5533471026087989, 'l...
#
#   outsample_excess_return_with_cost universe region qlib_market provider_uri  \
# 0                              None      NaN    NaN         NaN          NaN
# 1                              None      NaN    NaN         NaN          NaN
# 2                              None      NaN    NaN         NaN          NaN
# 3                              None      NaN    NaN         NaN          NaN
# 4                              None      NaN    NaN         NaN          NaN
#
#   benchmark_code enable_stage2 enable_stage3
# 0            NaN           NaN           NaN
# 1            NaN           NaN           NaN
# 2            NaN           NaN           NaN
# 3            NaN           NaN           NaN
# 4            NaN           NaN           NaN

# %%
ex_flat = pd.json_normalize(df_raw["outsample_excess_return_with_cost"])
df = pd.concat([df_raw.drop(columns=["outsample_excess_return_with_cost"]), ex_flat], axis=1)

df = df.sort_values(by='information_ratio', ascending=False)
df.head(20)
# Out:
#                run_id    outer_iter                         hypothesis_id  \
# 4388  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 6600  20260206_142717  outer_iter_5                BH_MR_Exhaustion_6D_v5
# 7112  20260206_144300  outer_iter_2        BH_Continuation_Pullback_7D_v2
# 6880  20260206_142717  outer_iter_5                BH_MR_Exhaustion_6D_v5
# 4472  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 6949  20260206_142717  outer_iter_5                BH_MR_Exhaustion_6D_v5
# 4493  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 3489  20260205_033043  outer_iter_2  BH_CT_Uptrend_Volume_Pullback_15D_v2
# 4373  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 3424  20260205_033043  outer_iter_1         BH_CT_Uptrend_Pullback_10D_v1
# 950   20260201_061954  outer_iter_1              BH_MR_ShortTermDip_3D_v1
# 3491  20260205_033043  outer_iter_2  BH_CT_Uptrend_Volume_Pullback_15D_v2
# 4478  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 4490  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 6588  20260206_142717  outer_iter_5                BH_MR_Exhaustion_6D_v5
# 3745  20260205_071052  outer_iter_1           BH_C_UptrendPullback_20D_v1
# 4731  20260206_002735          root                BH_MR_Exhaustion_5D_v1
# 6917  20260206_142717  outer_iter_5                BH_MR_Exhaustion_6D_v5
# 6192  20260206_142717  outer_iter_3                BH_MR_Exhaustion_5D_v3
# 3224  20260205_013521  outer_iter_1            TH_Uptrend_Pullback_10D_v1
#
#      backtest_mode  horizon_days         in_sample_period  \
# 4388   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 6600   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 7112   qlib_legacy           7.0  2015-01-01 ~ 2020-12-31
# 6880   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 4472   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 6949   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 4493   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 3489   qlib_native          15.0  2015-01-01 ~ 2020-12-31
# 4373   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 3424   qlib_native          10.0  2015-01-01 ~ 2020-12-31
# 950    qlib_native           3.0  2015-01-01 ~ 2020-12-31
# 3491   qlib_native          15.0  2015-01-01 ~ 2020-12-31
# 4478   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 4490   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 6588   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 3745   qlib_native          10.0  2015-01-01 ~ 2020-12-31
# 4731   qlib_native           5.0  2015-01-01 ~ 2020-12-31
# 6917   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 6192   qlib_legacy           5.0  2015-01-01 ~ 2020-12-31
# 3224   qlib_native          10.0  2015-01-01 ~ 2020-12-31
#
#             out_sample_period combo_idx       mode  threshold_q  ...  \
# 4388  2021-01-01 ~ 2025-12-31        30  fixed_q90         0.90  ...
# 6600  2021-01-01 ~ 2025-12-31        42     optuna          NaN  ...
# 7112  2021-01-01 ~ 2025-12-31         7     optuna          NaN  ...
# 6880  2021-01-01 ~ 2025-12-31       112     optuna          NaN  ...
# 4472  2021-01-01 ~ 2025-12-31        58  fixed_q90         0.90  ...
# 6949  2021-01-01 ~ 2025-12-31       129  fixed_q80         0.80  ...
# 4493  2021-01-01 ~ 2025-12-31        65  fixed_q90         0.90  ...
# 3489  2021-01-01 ~ 2025-12-31         4     optuna          NaN  ...
# 4373  2021-01-01 ~ 2025-12-31        25  fixed_q90         0.90  ...
# 3424  2021-01-01 ~ 2025-12-31        38  fixed_q80         0.80  ...
# 950   2021-01-01 ~ 2025-12-31         3  fixed_q80         0.80  ...
# 3491  2021-01-01 ~ 2025-12-31         4  fixed_q90         0.90  ...
# 4478  2021-01-01 ~ 2025-12-31        60  fixed_q90         0.90  ...
# 4490  2021-01-01 ~ 2025-12-31        64  fixed_q90         0.90  ...
# 6588  2021-01-01 ~ 2025-12-31        39     optuna          NaN  ...
# 3745  2021-01-01 ~ 2025-12-31         5  fixed_q80         0.80  ...
# 4731  2021-01-01 ~ 2025-12-31        13  fixed_q95         0.95  ...
# 6917  2021-01-01 ~ 2025-12-31       121  fixed_q80         0.80  ...
# 6192  2021-01-01 ~ 2025-12-31        75     optuna          NaN  ...
# 3224  2021-01-01 ~ 2025-12-31        42  fixed_q90         0.90  ...
#
#                    provider_uri benchmark_code enable_stage2 enable_stage3  \
# 4388  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 6600  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 7112  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 6880  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 4472  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 6949  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 4493  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 3489  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 4373  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 3424  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 950                         NaN            NaN           NaN           NaN
# 3491  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 4478  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 4490  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 6588  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 3745  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 4731  ~/.qlib/qlib_data/cn_data       SH000905         False          True
# 6917  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 6192  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 3224  ~/.qlib/qlib_data/cn_data       SH000905          None          None
#
#           mean       std annualized_return information_ratio  max_drawdown  \
# 4388  0.001375  0.022275          0.327144          0.951998     -0.571271
# 6600  0.001163  0.018888          0.276721          0.949681     -0.386825
# 7112  0.000997  0.017207          0.237334          0.894068     -0.347491
# 6880  0.001024  0.018122          0.243830          0.872137     -0.304664
# 4472  0.001010  0.018586          0.240428          0.838493     -0.439179
# 6949  0.001187  0.022146          0.282603          0.827177     -0.514403
# 4493  0.001086  0.020751          0.258520          0.807530     -0.379159
# 3489  0.001301  0.024976          0.309696          0.803762     -0.587617
# 4373  0.001138  0.022153          0.270783          0.792315     -0.583788
# 3424  0.000942  0.018711          0.224272          0.776929     -0.325594
# 950   0.000620  0.012330          0.147599          0.775968     -0.198011
# 3491  0.001104  0.023006          0.262764          0.740344     -0.396087
# 4478  0.000968  0.020599          0.230474          0.725243     -0.415840
# 4490  0.000855  0.018192          0.203497          0.725100     -0.463072
# 6588  0.000819  0.017576          0.194957          0.718996     -0.306899
# 3745  0.000764  0.016629          0.181719          0.708326     -0.369322
# 4731  0.000666  0.014780          0.158555          0.695360     -0.264654
# 6917  0.001024  0.022756          0.243808          0.694480     -0.557460
# 6192  0.000674  0.015580          0.160419          0.667401     -0.341573
# 3224  0.000839  0.019406          0.199721          0.667120     -0.465790
#
#       net_return
# 4388    2.928009
# 6600    2.299942
# 7112    1.803519
# 6880    1.838535
# 4472    1.765148
# 6949    2.142795
# 4493    1.881021
# 3489    2.327748
# 4373    1.959014
# 3424    1.533039
# 950     0.980118
# 3491    1.773146
# 4478    1.507777
# 4490    1.312401
# 6588    1.238495
# 3745    1.139421
# 4731    0.968205
# 6917    1.540014
# 6192    0.954390
# 3224    1.202577
#
# [20 rows x 24 columns]

# %%
df.query('region =="cn"').sort_values(by='information_ratio', ascending=False).head(20)
# Out:
#                run_id    outer_iter                         hypothesis_id  \
# 4388  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 6600  20260206_142717  outer_iter_5                BH_MR_Exhaustion_6D_v5
# 7112  20260206_144300  outer_iter_2        BH_Continuation_Pullback_7D_v2
# 6880  20260206_142717  outer_iter_5                BH_MR_Exhaustion_6D_v5
# 4472  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 6949  20260206_142717  outer_iter_5                BH_MR_Exhaustion_6D_v5
# 4493  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 3489  20260205_033043  outer_iter_2  BH_CT_Uptrend_Volume_Pullback_15D_v2
# 4373  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 3424  20260205_033043  outer_iter_1         BH_CT_Uptrend_Pullback_10D_v1
# 3491  20260205_033043  outer_iter_2  BH_CT_Uptrend_Volume_Pullback_15D_v2
# 4478  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 4490  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 6588  20260206_142717  outer_iter_5                BH_MR_Exhaustion_6D_v5
# 3745  20260205_071052  outer_iter_1           BH_C_UptrendPullback_20D_v1
# 4731  20260206_002735          root                BH_MR_Exhaustion_5D_v1
# 6917  20260206_142717  outer_iter_5                BH_MR_Exhaustion_6D_v5
# 6192  20260206_142717  outer_iter_3                BH_MR_Exhaustion_5D_v3
# 3224  20260205_013521  outer_iter_1            TH_Uptrend_Pullback_10D_v1
# 3495  20260205_033043  outer_iter_2  BH_CT_Uptrend_Volume_Pullback_15D_v2
#
#      backtest_mode  horizon_days         in_sample_period  \
# 4388   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 6600   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 7112   qlib_legacy           7.0  2015-01-01 ~ 2020-12-31
# 6880   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 4472   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 6949   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 4493   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 3489   qlib_native          15.0  2015-01-01 ~ 2020-12-31
# 4373   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 3424   qlib_native          10.0  2015-01-01 ~ 2020-12-31
# 3491   qlib_native          15.0  2015-01-01 ~ 2020-12-31
# 4478   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 4490   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 6588   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 3745   qlib_native          10.0  2015-01-01 ~ 2020-12-31
# 4731   qlib_native           5.0  2015-01-01 ~ 2020-12-31
# 6917   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 6192   qlib_legacy           5.0  2015-01-01 ~ 2020-12-31
# 3224   qlib_native          10.0  2015-01-01 ~ 2020-12-31
# 3495   qlib_native          15.0  2015-01-01 ~ 2020-12-31
#
#             out_sample_period combo_idx       mode  threshold_q  ...  \
# 4388  2021-01-01 ~ 2025-12-31        30  fixed_q90         0.90  ...
# 6600  2021-01-01 ~ 2025-12-31        42     optuna          NaN  ...
# 7112  2021-01-01 ~ 2025-12-31         7     optuna          NaN  ...
# 6880  2021-01-01 ~ 2025-12-31       112     optuna          NaN  ...
# 4472  2021-01-01 ~ 2025-12-31        58  fixed_q90         0.90  ...
# 6949  2021-01-01 ~ 2025-12-31       129  fixed_q80         0.80  ...
# 4493  2021-01-01 ~ 2025-12-31        65  fixed_q90         0.90  ...
# 3489  2021-01-01 ~ 2025-12-31         4     optuna          NaN  ...
# 4373  2021-01-01 ~ 2025-12-31        25  fixed_q90         0.90  ...
# 3424  2021-01-01 ~ 2025-12-31        38  fixed_q80         0.80  ...
# 3491  2021-01-01 ~ 2025-12-31         4  fixed_q90         0.90  ...
# 4478  2021-01-01 ~ 2025-12-31        60  fixed_q90         0.90  ...
# 4490  2021-01-01 ~ 2025-12-31        64  fixed_q90         0.90  ...
# 6588  2021-01-01 ~ 2025-12-31        39     optuna          NaN  ...
# 3745  2021-01-01 ~ 2025-12-31         5  fixed_q80         0.80  ...
# 4731  2021-01-01 ~ 2025-12-31        13  fixed_q95         0.95  ...
# 6917  2021-01-01 ~ 2025-12-31       121  fixed_q80         0.80  ...
# 6192  2021-01-01 ~ 2025-12-31        75     optuna          NaN  ...
# 3224  2021-01-01 ~ 2025-12-31        42  fixed_q90         0.90  ...
# 3495  2021-01-01 ~ 2025-12-31         6     optuna          NaN  ...
#
#                    provider_uri benchmark_code enable_stage2 enable_stage3  \
# 4388  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 6600  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 7112  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 6880  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 4472  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 6949  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 4493  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 3489  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 4373  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 3424  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 3491  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 4478  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 4490  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 6588  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 3745  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 4731  ~/.qlib/qlib_data/cn_data       SH000905         False          True
# 6917  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 6192  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 3224  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 3495  ~/.qlib/qlib_data/cn_data       SH000905          None          None
#
#           mean       std annualized_return information_ratio  max_drawdown  \
# 4388  0.001375  0.022275          0.327144          0.951998     -0.571271
# 6600  0.001163  0.018888          0.276721          0.949681     -0.386825
# 7112  0.000997  0.017207          0.237334          0.894068     -0.347491
# 6880  0.001024  0.018122          0.243830          0.872137     -0.304664
# 4472  0.001010  0.018586          0.240428          0.838493     -0.439179
# 6949  0.001187  0.022146          0.282603          0.827177     -0.514403
# 4493  0.001086  0.020751          0.258520          0.807530     -0.379159
# 3489  0.001301  0.024976          0.309696          0.803762     -0.587617
# 4373  0.001138  0.022153          0.270783          0.792315     -0.583788
# 3424  0.000942  0.018711          0.224272          0.776929     -0.325594
# 3491  0.001104  0.023006          0.262764          0.740344     -0.396087
# 4478  0.000968  0.020599          0.230474          0.725243     -0.415840
# 4490  0.000855  0.018192          0.203497          0.725100     -0.463072
# 6588  0.000819  0.017576          0.194957          0.718996     -0.306899
# 3745  0.000764  0.016629          0.181719          0.708326     -0.369322
# 4731  0.000666  0.014780          0.158555          0.695360     -0.264654
# 6917  0.001024  0.022756          0.243808          0.694480     -0.557460
# 6192  0.000674  0.015580          0.160419          0.667401     -0.341573
# 3224  0.000839  0.019406          0.199721          0.667120     -0.465790
# 3495  0.000707  0.016814          0.168265          0.648688     -0.371625
#
#       net_return
# 4388    2.928009
# 6600    2.299942
# 7112    1.803519
# 6880    1.838535
# 4472    1.765148
# 6949    2.142795
# 4493    1.881021
# 3489    2.327748
# 4373    1.959014
# 3424    1.533039
# 3491    1.773146
# 4478    1.507777
# 4490    1.312401
# 6588    1.238495
# 3745    1.139421
# 4731    0.968205
# 6917    1.540014
# 6192    0.954390
# 3224    1.202577
# 3495    0.984047
#
# [20 rows x 24 columns]

# %%
df.sort_values(by='information_ratio', ascending=False).head(20).query('region !="cn"')
# Out:
#               run_id    outer_iter             hypothesis_id backtest_mode  \
# 950  20260201_061954  outer_iter_1  BH_MR_ShortTermDip_3D_v1   qlib_native
#
#      horizon_days         in_sample_period        out_sample_period combo_idx  \
# 950           3.0  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         3
#
#           mode  threshold_q  ... provider_uri benchmark_code enable_stage2  \
# 950  fixed_q80          0.8  ...          NaN            NaN           NaN
#
#     enable_stage3     mean      std annualized_return information_ratio  \
# 950           NaN  0.00062  0.01233          0.147599          0.775968
#
#      max_drawdown  net_return
# 950     -0.198011    0.980118
#
# [1 rows x 24 columns]

# %%
df.query('enable_stage2 == True & enable_stage3 == True').sort_values(by='information_ratio', ascending=False)#.head(20)
# Out:
#                run_id    outer_iter                   hypothesis_id  \
# 6600  20260206_142717  outer_iter_5          BH_MR_Exhaustion_6D_v5
# 7112  20260206_144300  outer_iter_2  BH_Continuation_Pullback_7D_v2
# 6880  20260206_142717  outer_iter_5          BH_MR_Exhaustion_6D_v5
# 6949  20260206_142717  outer_iter_5          BH_MR_Exhaustion_6D_v5
# 6588  20260206_142717  outer_iter_5          BH_MR_Exhaustion_6D_v5
# ...               ...           ...                             ...
# 5190  20260206_110646  outer_iter_1    BH_MR_IntradayRecovery_3D_v1
# 5231  20260206_110646  outer_iter_1    BH_MR_IntradayRecovery_3D_v1
# 5230  20260206_110646  outer_iter_1    BH_MR_IntradayRecovery_3D_v1
# 5154  20260206_110646  outer_iter_1    BH_MR_IntradayRecovery_3D_v1
# 5202  20260206_110646  outer_iter_1    BH_MR_IntradayRecovery_3D_v1
#
#      backtest_mode  horizon_days         in_sample_period  \
# 6600   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 7112   qlib_legacy           7.0  2015-01-01 ~ 2020-12-31
# 6880   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 6949   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 6588   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# ...            ...           ...                      ...
# 5190   qlib_legacy           3.0  2015-01-01 ~ 2020-12-31
# 5231   qlib_legacy           3.0  2015-01-01 ~ 2020-12-31
# 5230   qlib_legacy           3.0  2015-01-01 ~ 2020-12-31
# 5154   qlib_legacy           3.0  2015-01-01 ~ 2020-12-31
# 5202   qlib_legacy           3.0  2015-01-01 ~ 2020-12-31
#
#             out_sample_period combo_idx       mode  threshold_q  ...  \
# 6600  2021-01-01 ~ 2025-12-31        42     optuna          NaN  ...
# 7112  2021-01-01 ~ 2025-12-31         7     optuna          NaN  ...
# 6880  2021-01-01 ~ 2025-12-31       112     optuna          NaN  ...
# 6949  2021-01-01 ~ 2025-12-31       129  fixed_q80         0.80  ...
# 6588  2021-01-01 ~ 2025-12-31        39     optuna          NaN  ...
# ...                       ...       ...        ...          ...  ...
# 5190  2021-01-01 ~ 2025-12-31        16  fixed_q90         0.90  ...
# 5231  2021-01-01 ~ 2025-12-31        26  fixed_q95         0.95  ...
# 5230  2021-01-01 ~ 2025-12-31        26  fixed_q90         0.90  ...
# 5154  2021-01-01 ~ 2025-12-31         7  fixed_q90         0.90  ...
# 5202  2021-01-01 ~ 2025-12-31        19  fixed_q90         0.90  ...
#
#                    provider_uri benchmark_code enable_stage2 enable_stage3  \
# 6600  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 7112  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 6880  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 6949  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 6588  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# ...                         ...            ...           ...           ...
# 5190  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 5231  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 5230  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 5154  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 5202  ~/.qlib/qlib_data/cn_data       SH000905          True          True
#
#           mean       std annualized_return information_ratio  max_drawdown  \
# 6600  0.001163  0.018888          0.276721          0.949681     -0.386825
# 7112  0.000997  0.017207          0.237334          0.894068     -0.347491
# 6880  0.001024  0.018122          0.243830          0.872137     -0.304664
# 6949  0.001187  0.022146          0.282603          0.827177     -0.514403
# 6588  0.000819  0.017576          0.194957          0.718996     -0.306899
# ...        ...       ...               ...               ...           ...
# 5190 -0.001858  0.014417         -0.442321         -1.988744     -2.314503
# 5231 -0.002118  0.015931         -0.504052         -2.050881     -2.631439
# 5230 -0.001985  0.014796         -0.472420         -2.069594     -2.441322
# 5154 -0.002331  0.014892         -0.554685         -2.414431     -2.863814
# 5202 -0.002457  0.015297         -0.584766         -2.477962     -3.001964
#
#       net_return
# 6600    2.299942
# 7112    1.803519
# 6880    1.838535
# 6949    2.142795
# 6588    1.238495
# ...          ...
# 5190   -0.907175
# 5231   -0.934060
# 5230   -0.920867
# 5154   -0.948084
# 5202   -0.955782
#
# [3729 rows x 24 columns]

# %%
df.query('enable_stage2 == False & enable_stage3 == True').sort_values(by='information_ratio', ascending=False)#.head(20)
# Out:
#                run_id    outer_iter  \
# 4731  20260206_002735          root
# 4736  20260206_002735          root
# 4907  20260206_011826  outer_iter_1
# 4691  20260206_002735          root
# 4846  20260206_011826  outer_iter_1
# ...               ...           ...
# 4816  20260206_002735          root
# 4916  20260206_011826  outer_iter_2
# 4908  20260206_011826  outer_iter_2
# 4924  20260206_011826  outer_iter_2
# 4680  20260206_002735          root
#
#                                    hypothesis_id backtest_mode  horizon_days  \
# 4731                      BH_MR_Exhaustion_5D_v1   qlib_native           5.0
# 4736                      BH_MR_Exhaustion_5D_v1   qlib_native           5.0
# 4907            BH_Uptrend_Pullback_Retest_7D_v1   qlib_native           7.0
# 4691                      BH_MR_Exhaustion_5D_v1   qlib_native           5.0
# 4846            BH_Uptrend_Pullback_Retest_7D_v1   qlib_native           7.0
# ...                                          ...           ...           ...
# 4816                      BH_MR_Exhaustion_5D_v1   qlib_native           5.0
# 4916  BH_Uptrend_Pullback_ProfitTaker_Fade_2D_v1   qlib_native           2.0
# 4908  BH_Uptrend_Pullback_ProfitTaker_Fade_2D_v1   qlib_native           2.0
# 4924  BH_Uptrend_Pullback_ProfitTaker_Fade_2D_v1   qlib_native           2.0
# 4680                      BH_MR_Exhaustion_5D_v1   qlib_native           5.0
#
#              in_sample_period        out_sample_period combo_idx       mode  \
# 4731  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31        13  fixed_q95
# 4736  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31        15     optuna
# 4907  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31        18  fixed_q95
# 4691  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         3  fixed_q95
# 4846  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         3  fixed_q90
# ...                       ...                      ...       ...        ...
# 4816  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31        35     optuna
# 4916  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         3     optuna
# 4908  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1     optuna
# 4924  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         5     optuna
# 4680  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1     optuna
#
#       threshold_q  ...               provider_uri benchmark_code  \
# 4731         0.95  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 4736          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 4907         0.95  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 4691         0.95  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 4846         0.90  ...  ~/.qlib/qlib_data/cn_data       SH000905
# ...           ...  ...                        ...            ...
# 4816          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 4916          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 4908          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 4924          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 4680          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
#
#      enable_stage2 enable_stage3      mean       std annualized_return  \
# 4731         False          True  0.000666  0.014780          0.158555
# 4736         False          True  0.000675  0.016873          0.160581
# 4907         False          True  0.000328  0.015327          0.078153
# 4691         False          True  0.000304  0.014552          0.072352
# 4846         False          True  0.000282  0.014505          0.067024
# ...            ...           ...       ...       ...               ...
# 4816         False          True -0.001267  0.013914         -0.301632
# 4916         False          True -0.001433  0.015571         -0.341044
# 4908         False          True -0.001158  0.012228         -0.275593
# 4924         False          True -0.001509  0.014345         -0.359085
# 4680         False          True -0.001562  0.014286         -0.371816
#
#      information_ratio  max_drawdown  net_return
# 4731          0.695360     -0.264654    0.968205
# 4736          0.616896     -0.332605    0.908472
# 4907          0.330525     -0.420933    0.293113
# 4691          0.322274     -0.369197    0.272380
# 4846          0.299526     -0.398729    0.238678
# ...                ...           ...         ...
# 4816         -1.405203     -1.514934   -0.808210
# 4916         -1.419712     -1.794641   -0.847786
# 4908         -1.460947     -1.426106   -0.775229
# 4924         -1.622626     -1.975731   -0.858003
# 4680         -1.687063     -1.883847   -0.866714
#
# [368 rows x 24 columns]

# %%
df.query('enable_stage2 == True & enable_stage3 == False').sort_values(by='information_ratio', ascending=False)
# Out:
#                run_id    outer_iter hypothesis_id backtest_mode  horizon_days  \
# 8567  20260208_020647  outer_iter_2                 qlib_legacy           7.0
# 8564  20260208_020647  outer_iter_1                 qlib_native           5.0
# 8570  20260208_020647  outer_iter_3                 qlib_native           3.0
# 8573  20260208_020647  outer_iter_4                 qlib_native           9.0
# 8574  20260208_020647  outer_iter_4                 qlib_native           9.0
# 8575  20260208_020647  outer_iter_4                 qlib_native           9.0
# 8576  20260208_020647  outer_iter_5                 qlib_native           8.0
# 8577  20260208_020647  outer_iter_5                 qlib_native           8.0
# 8565  20260208_020647  outer_iter_1                 qlib_native           5.0
# 8566  20260208_020647  outer_iter_1                 qlib_native           5.0
# 8569  20260208_020647  outer_iter_2                 qlib_legacy           7.0
# 8571  20260208_020647  outer_iter_3                 qlib_native           3.0
# 8572  20260208_020647  outer_iter_3                 qlib_native           3.0
# 8578  20260208_020647  outer_iter_5                 qlib_native           8.0
# 8568  20260208_020647  outer_iter_2                 qlib_legacy           7.0
# 8608  20260209_001858  outer_iter_1                     skipped           5.0
# 8607  20260209_001858  outer_iter_1                     skipped           5.0
# 8612  20260209_001858  outer_iter_3                     skipped           9.0
# 8611  20260209_001858  outer_iter_3                     skipped           9.0
# 8610  20260209_001858  outer_iter_2                     skipped           3.0
# 8609  20260209_001858  outer_iter_2                     skipped           3.0
# 8613  20260209_001858  outer_iter_4                     skipped           7.0
# 8614  20260209_001858  outer_iter_4                     skipped           7.0
#
#              in_sample_period        out_sample_period combo_idx       mode  \
# 8567  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1     optuna
# 8564  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1     optuna
# 8570  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1     optuna
# 8573  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1     optuna
# 8574  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q80
# 8575  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q90
# 8576  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1     optuna
# 8577  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q80
# 8565  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q80
# 8566  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q90
# 8569  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q90
# 8571  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q80
# 8572  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q90
# 8578  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q90
# 8568  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q80
# 8608                     None                     None         1  fixed_q90
# 8607                     None                     None         1     optuna
# 8612                     None                     None         1  fixed_q90
# 8611                     None                     None         1     optuna
# 8610                     None                     None         1  fixed_q90
# 8609                     None                     None         1     optuna
# 8613                     None                     None         1     optuna
# 8614                     None                     None         1  fixed_q90
#
#       threshold_q  ...               provider_uri benchmark_code  \
# 8567          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8564          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8570          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8573          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8574          0.8  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8575          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8576          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8577          0.8  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8565          0.8  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8566          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8569          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8571          0.8  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8572          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8578          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8568          0.8  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8608          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8607          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8612          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8611          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8610          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8609          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8613          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8614          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
#
#      enable_stage2 enable_stage3      mean       std annualized_return  \
# 8567          True         False -0.000098  0.015596         -0.023377
# 8564          True         False -0.000199  0.013033         -0.047300
# 8570          True         False -0.000212  0.013032         -0.050564
# 8573          True         False -0.000212  0.013032         -0.050564
# 8574          True         False -0.000212  0.013032         -0.050564
# 8575          True         False -0.000212  0.013032         -0.050564
# 8576          True         False -0.000212  0.013032         -0.050564
# 8577          True         False -0.000212  0.013032         -0.050564
# 8565          True         False -0.000212  0.013032         -0.050564
# 8566          True         False -0.000212  0.013032         -0.050564
# 8569          True         False -0.000212  0.013032         -0.050564
# 8571          True         False -0.000212  0.013032         -0.050564
# 8572          True         False -0.000212  0.013032         -0.050564
# 8578          True         False -0.000212  0.013032         -0.050564
# 8568          True         False -0.000271  0.013031         -0.064463
# 8608          True         False -0.000459  0.019999         -0.109358
# 8607          True         False -0.000459  0.019999         -0.109358
# 8612          True         False -0.000404  0.016548         -0.096064
# 8611          True         False -0.000404  0.016548         -0.096064
# 8610          True         False -0.000379  0.014303         -0.090168
# 8609          True         False -0.000379  0.014303         -0.090168
# 8613          True         False -0.000568  0.017955         -0.135280
# 8614          True         False -0.000568  0.017955         -0.135280
#
#      information_ratio  max_drawdown  net_return
# 8567         -0.097161     -0.465341   -0.233272
# 8564         -0.235243     -0.577391   -0.290694
# 8570         -0.251508     -0.577391   -0.302355
# 8573         -0.251508     -0.577391   -0.302355
# 8574         -0.251508     -0.577391   -0.302355
# 8575         -0.251508     -0.577391   -0.302355
# 8576         -0.251508     -0.577391   -0.302355
# 8577         -0.251508     -0.577391   -0.302355
# 8565         -0.251508     -0.577391   -0.302355
# 8566         -0.251508     -0.577391   -0.302355
# 8569         -0.251508     -0.577391   -0.302355
# 8571         -0.251508     -0.577391   -0.302355
# 8572         -0.251508     -0.577391   -0.302355
# 8578         -0.251508     -0.577391   -0.302355
# 8568         -0.320672     -0.577391   -0.349964
# 8608         -0.354448     -0.948483   -0.548245
# 8607         -0.354448     -0.948483   -0.548245
# 8612         -0.376284     -0.957886   -0.479619
# 8611         -0.376284     -0.957886   -0.479619
# 8610         -0.408651     -0.743323   -0.441419
# 8609         -0.408651     -0.743323   -0.441419
# 8613         -0.488393     -0.965466   -0.584505
# 8614         -0.488393     -0.965466   -0.584505
#
# [23 rows x 24 columns]

# %%
df.query('enable_stage2 == False & enable_stage3 == False').sort_values(by='information_ratio', ascending=False)#.head(20)
# Out:
#                run_id    outer_iter hypothesis_id backtest_mode  horizon_days  \
# 8598  20260209_001734  outer_iter_1                     skipped           5.0
# 8597  20260209_001734  outer_iter_1                     skipped           5.0
# 8606  20260209_001734  outer_iter_5                     skipped           2.0
# 8605  20260209_001734  outer_iter_5                     skipped           2.0
# 8596  20260208_055103  outer_iter_1                 qlib_native           4.0
# 8595  20260208_055103  outer_iter_1                 qlib_native           4.0
# 8594  20260208_055103  outer_iter_1                 qlib_native           4.0
# 8582  20260208_022121  outer_iter_2                 qlib_native           6.0
# 8584  20260208_022121  outer_iter_2                 qlib_native           6.0
# 8585  20260208_022121  outer_iter_3                 qlib_native           4.0
# 8583  20260208_022121  outer_iter_2                 qlib_native           6.0
# 8604  20260209_001734  outer_iter_4                     skipped           6.0
# 8588  20260208_022121  outer_iter_4                 qlib_native           8.0
# 8581  20260208_022121  outer_iter_1                 qlib_native           3.0
# 8589  20260208_022121  outer_iter_4                 qlib_native           8.0
# 8590  20260208_022121  outer_iter_4                 qlib_native           8.0
# 8603  20260209_001734  outer_iter_4                     skipped           6.0
# 8591  20260208_022121  outer_iter_5                 qlib_native           7.0
# 8593  20260208_022121  outer_iter_5                 qlib_native           7.0
# 8579  20260208_022121  outer_iter_1                 qlib_native           3.0
# 8586  20260208_022121  outer_iter_3                 qlib_native           4.0
# 8592  20260208_022121  outer_iter_5                 qlib_native           7.0
# 8580  20260208_022121  outer_iter_1                 qlib_native           3.0
# 8587  20260208_022121  outer_iter_3                 qlib_native           4.0
# 8602  20260209_001734  outer_iter_3                     skipped           3.0
# 8601  20260209_001734  outer_iter_3                     skipped           3.0
# 8600  20260209_001734  outer_iter_2                     skipped           7.0
# 8599  20260209_001734  outer_iter_2                     skipped           7.0
#
#              in_sample_period        out_sample_period combo_idx       mode  \
# 8598                     None                     None         1  fixed_q90
# 8597                     None                     None         1     optuna
# 8606                     None                     None         1  fixed_q90
# 8605                     None                     None         1     optuna
# 8596                     None                     None         1  fixed_q90
# 8595                     None                     None         1  fixed_q80
# 8594                     None                     None         1     optuna
# 8582  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1     optuna
# 8584  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q90
# 8585  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1     optuna
# 8583  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q80
# 8604                     None                     None         1  fixed_q90
# 8588  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1     optuna
# 8581  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q90
# 8589  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q80
# 8590  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q90
# 8603                     None                     None         1     optuna
# 8591  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1     optuna
# 8593  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q90
# 8579  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1     optuna
# 8586  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q80
# 8592  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q80
# 8580  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q80
# 8587  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1  fixed_q90
# 8602                     None                     None         1  fixed_q90
# 8601                     None                     None         1     optuna
# 8600                     None                     None         1  fixed_q90
# 8599                     None                     None         1     optuna
#
#       threshold_q  ...               provider_uri benchmark_code  \
# 8598          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8597          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8606          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8605          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8596          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8595          0.8  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8594          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8582          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8584          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8585          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8583          0.8  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8604          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8588          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8581          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8589          0.8  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8590          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8603          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8591          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8593          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8579          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8586          0.8  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8592          0.8  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8580          0.8  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8587          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8602          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8601          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8600          0.9  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8599          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
#
#      enable_stage2 enable_stage3      mean       std annualized_return  \
# 8598         False         False  0.000074  0.020867          0.017584
# 8597         False         False  0.000074  0.020867          0.017584
# 8606         False         False -0.000052  0.016892         -0.012491
# 8605         False         False -0.000052  0.016892         -0.012491
# 8596         False         False -0.000141  0.014315         -0.033527
# 8595         False         False -0.000141  0.014315         -0.033527
# 8594         False         False -0.000141  0.014315         -0.033527
# 8582         False         False -0.000180  0.013440         -0.042873
# 8584         False         False -0.000212  0.013032         -0.050564
# 8585         False         False -0.000212  0.013032         -0.050564
# 8583         False         False -0.000212  0.013032         -0.050564
# 8604         False         False -0.000212  0.013032         -0.050564
# 8588         False         False -0.000212  0.013032         -0.050564
# 8581         False         False -0.000212  0.013032         -0.050564
# 8589         False         False -0.000212  0.013032         -0.050564
# 8590         False         False -0.000212  0.013032         -0.050564
# 8603         False         False -0.000212  0.013032         -0.050564
# 8591         False         False -0.000212  0.013032         -0.050564
# 8593         False         False -0.000212  0.013032         -0.050564
# 8579         False         False -0.000212  0.013032         -0.050564
# 8586         False         False -0.000212  0.013032         -0.050564
# 8592         False         False -0.000212  0.013032         -0.050564
# 8580         False         False -0.000212  0.013032         -0.050564
# 8587         False         False -0.000212  0.013032         -0.050564
# 8602         False         False -0.000445  0.015538         -0.105800
# 8601         False         False -0.000445  0.015538         -0.105800
# 8600         False         False -0.000748  0.019824         -0.178014
# 8599         False         False -0.000748  0.019824         -0.178014
#
#      information_ratio  max_drawdown  net_return
# 8598          0.054622     -0.797436   -0.158390
# 8597          0.054622     -0.797436   -0.158390
# 8606         -0.047932     -1.185993   -0.206408
# 8605         -0.047932     -1.185993   -0.206408
# 8596         -0.151815     -0.538171   -0.253039
# 8595         -0.151815     -0.538171   -0.253039
# 8594         -0.151815     -0.538171   -0.253039
# 8582         -0.206778     -0.615928   -0.279033
# 8584         -0.251508     -0.577391   -0.302355
# 8585         -0.251508     -0.577391   -0.302355
# 8583         -0.251508     -0.577391   -0.302355
# 8604         -0.251508     -0.577391   -0.302355
# 8588         -0.251508     -0.577391   -0.302355
# 8581         -0.251508     -0.577391   -0.302355
# 8589         -0.251508     -0.577391   -0.302355
# 8590         -0.251508     -0.577391   -0.302355
# 8603         -0.251508     -0.577391   -0.302355
# 8591         -0.251508     -0.577391   -0.302355
# 8593         -0.251508     -0.577391   -0.302355
# 8579         -0.251508     -0.577391   -0.302355
# 8586         -0.251508     -0.577391   -0.302355
# 8592         -0.251508     -0.577391   -0.302355
# 8580         -0.251508     -0.577391   -0.302355
# 8587         -0.251508     -0.577391   -0.302355
# 8602         -0.441358     -0.772522   -0.494907
# 8601         -0.441358     -0.772522   -0.494907
# 8600         -0.582076     -0.969823   -0.680535
# 8599         -0.582076     -0.969823   -0.680535
#
# [28 rows x 24 columns]

# %%
df.query('region =="us"').sort_values(by='information_ratio', ascending=False).head(20)
# Out:
#                run_id    outer_iter               hypothesis_id  \
# 8739  20260209_014429  outer_iter_1     BH_Trend_Pullback_5D_v1
# 938   20260131_041725          root  BH_SR_SelloffRebound_3D_v1
# 8775  20260209_072854  outer_iter_1    BH_MR_PanicSelling_5D_v1
# 8762  20260209_072854  outer_iter_1    BH_MR_PanicSelling_5D_v1
# 8715  20260209_014429  outer_iter_1     BH_Trend_Pullback_5D_v1
# 937   20260131_041725          root  BH_SR_SelloffRebound_3D_v1
# 8763  20260209_072854  outer_iter_1    BH_MR_PanicSelling_5D_v1
# 8767  20260209_072854  outer_iter_1    BH_MR_PanicSelling_5D_v1
# 8705  20260209_014429  outer_iter_1     BH_Trend_Pullback_5D_v1
# 8731  20260209_014429  outer_iter_1     BH_Trend_Pullback_5D_v1
# 931   20260131_041725          root  BH_SR_SelloffRebound_3D_v1
# 8778  20260209_072854  outer_iter_1    BH_MR_PanicSelling_5D_v1
# 921   20260131_041725          root  BH_SR_SelloffRebound_3D_v1
# 8745  20260209_014429  outer_iter_1     BH_Trend_Pullback_5D_v1
# 8741  20260209_014429  outer_iter_1     BH_Trend_Pullback_5D_v1
# 8693  20260209_014429  outer_iter_1     BH_Trend_Pullback_5D_v1
# 8806  20260209_072854  outer_iter_1    BH_MR_PanicSelling_5D_v1
# 8768  20260209_072854  outer_iter_1    BH_MR_PanicSelling_5D_v1
# 8760  20260209_072854  outer_iter_1    BH_MR_PanicSelling_5D_v1
# 8766  20260209_072854  outer_iter_1    BH_MR_PanicSelling_5D_v1
#
#            backtest_mode  horizon_days         in_sample_period  \
# 8739             skipped           5.0                     None
# 938   per_combo_parallel           3.0  2015-01-01 ~ 2020-12-31
# 8775  per_combo_parallel           5.0  2015-01-01 ~ 2019-12-31
# 8762  per_combo_parallel           5.0  2015-01-01 ~ 2019-12-31
# 8715             skipped           5.0                     None
# 937   per_combo_parallel           3.0  2015-01-01 ~ 2020-12-31
# 8763  per_combo_parallel           5.0  2015-01-01 ~ 2019-12-31
# 8767  per_combo_parallel           5.0  2015-01-01 ~ 2019-12-31
# 8705             skipped           5.0                     None
# 8731             skipped           5.0                     None
# 931   per_combo_parallel           3.0  2015-01-01 ~ 2020-12-31
# 8778  per_combo_parallel           5.0  2015-01-01 ~ 2019-12-31
# 921   per_combo_parallel           3.0  2015-01-01 ~ 2020-12-31
# 8745             skipped           5.0                     None
# 8741             skipped           5.0                     None
# 8693             skipped           5.0                     None
# 8806  per_combo_parallel           5.0  2015-01-01 ~ 2019-12-31
# 8768  per_combo_parallel           5.0  2015-01-01 ~ 2019-12-31
# 8760  per_combo_parallel           5.0  2015-01-01 ~ 2019-12-31
# 8766  per_combo_parallel           5.0  2015-01-01 ~ 2019-12-31
#
#             out_sample_period combo_idx    mode  threshold_q  ...  \
# 8739                     None        24  optuna          NaN  ...
# 938   2021-01-01 ~ 2025-12-31        18  optuna          NaN  ...
# 8775  2021-01-01 ~ 2025-12-31        19  optuna          NaN  ...
# 8762  2021-01-01 ~ 2025-12-31         6  optuna          NaN  ...
# 8715                     None        12  optuna          NaN  ...
# 937   2021-01-01 ~ 2025-12-31        17  optuna          NaN  ...
# 8763  2021-01-01 ~ 2025-12-31         7  optuna          NaN  ...
# 8767  2021-01-01 ~ 2025-12-31        11  optuna          NaN  ...
# 8705                     None         7  optuna          NaN  ...
# 8731                     None        20  optuna          NaN  ...
# 931   2021-01-01 ~ 2025-12-31        11  optuna          NaN  ...
# 8778  2021-01-01 ~ 2025-12-31        22  optuna          NaN  ...
# 921   2021-01-01 ~ 2025-12-31         1  optuna          NaN  ...
# 8745                     None        27  optuna          NaN  ...
# 8741                     None        25  optuna          NaN  ...
# 8693                     None         1  optuna          NaN  ...
# 8806  2021-01-01 ~ 2025-12-31        50  optuna          NaN  ...
# 8768  2021-01-01 ~ 2025-12-31        12  optuna          NaN  ...
# 8760  2021-01-01 ~ 2025-12-31         4  optuna          NaN  ...
# 8766  2021-01-01 ~ 2025-12-31        10  optuna          NaN  ...
#
#                provider_uri benchmark_code enable_stage2 enable_stage3  \
# 8739  ~/.qlib/sh_sp500_qlib          ^GSPC          True          True
# 938   ~/.qlib/sh_sp500_qlib          ^GSPC          None          None
# 8775  ~/.qlib/sh_sp500_qlib          ^GSPC          True          True
# 8762  ~/.qlib/sh_sp500_qlib          ^GSPC          True          True
# 8715  ~/.qlib/sh_sp500_qlib          ^GSPC          True          True
# 937   ~/.qlib/sh_sp500_qlib          ^GSPC          None          None
# 8763  ~/.qlib/sh_sp500_qlib          ^GSPC          True          True
# 8767  ~/.qlib/sh_sp500_qlib          ^GSPC          True          True
# 8705  ~/.qlib/sh_sp500_qlib          ^GSPC          True          True
# 8731  ~/.qlib/sh_sp500_qlib          ^GSPC          True          True
# 931   ~/.qlib/sh_sp500_qlib          ^GSPC          None          None
# 8778  ~/.qlib/sh_sp500_qlib          ^GSPC          True          True
# 921   ~/.qlib/sh_sp500_qlib          ^GSPC          None          None
# 8745  ~/.qlib/sh_sp500_qlib          ^GSPC          True          True
# 8741  ~/.qlib/sh_sp500_qlib          ^GSPC          True          True
# 8693  ~/.qlib/sh_sp500_qlib          ^GSPC          True          True
# 8806  ~/.qlib/sh_sp500_qlib          ^GSPC          True          True
# 8768  ~/.qlib/sh_sp500_qlib          ^GSPC          True          True
# 8760  ~/.qlib/sh_sp500_qlib          ^GSPC          True          True
# 8766  ~/.qlib/sh_sp500_qlib          ^GSPC          True          True
#
#           mean       std annualized_return information_ratio  max_drawdown  \
# 8739  0.000510  0.015191          0.121482          0.518358     -0.433647
# 938   0.000143  0.018628          0.034145          0.118813     -0.375007
# 8775  0.000071  0.019168          0.016875          0.057067     -0.450246
# 8762  0.000046  0.021373          0.010899          0.033054     -0.355332
# 8715  0.000033  0.016426          0.007742          0.030551     -0.442941
# 937   0.000011  0.019673          0.002612          0.008606     -0.461104
# 8763  0.000002  0.020654          0.000365          0.001146     -0.456665
# 8767 -0.000015  0.020569         -0.003654         -0.011514     -0.439351
# 8705 -0.000027  0.013972         -0.006534         -0.030310     -0.864668
# 8731 -0.000067  0.016229         -0.015923         -0.063599     -0.717713
# 931  -0.000090  0.019331         -0.021528         -0.072189     -0.398115
# 8778 -0.000093  0.018742         -0.022056         -0.076284     -0.485060
# 921  -0.000103  0.018670         -0.024599         -0.085406     -0.473032
# 8745 -0.000098  0.015853         -0.023365         -0.095535     -0.583759
# 8741 -0.000105  0.013802         -0.025085         -0.117810     -0.623416
# 8693 -0.000124  0.014892         -0.029581         -0.128757     -0.628361
# 8806 -0.000151  0.017355         -0.035909         -0.134119     -0.548311
# 8768 -0.000186  0.020215         -0.044179         -0.141662     -0.634060
# 8760 -0.000208  0.021104         -0.049523         -0.152111     -0.459463
# 8766 -0.000218  0.020971         -0.051799         -0.160108     -0.607588
#
#       net_return
# 8739    0.646372
# 938    -0.036781
# 8775   -0.131380
# 8762   -0.208481
# 8715   -0.120788
# 937    -0.206608
# 8763   -0.232564
# 8767   -0.246897
# 8705   -0.145142
# 8731   -0.218735
# 931    -0.295243
# 8778   -0.285263
# 921    -0.292980
# 8745   -0.243627
# 8741   -0.221208
# 8693   -0.256041
# 8806   -0.315777
# 8768   -0.385951
# 8760   -0.417411
# 8766   -0.422283
#
# [20 rows x 24 columns]

# %%
df.sort_values(by='information_ratio', ascending=False).head(20)
# Out:
#                run_id    outer_iter                         hypothesis_id  \
# 4388  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 6600  20260206_142717  outer_iter_5                BH_MR_Exhaustion_6D_v5
# 7112  20260206_144300  outer_iter_2        BH_Continuation_Pullback_7D_v2
# 6880  20260206_142717  outer_iter_5                BH_MR_Exhaustion_6D_v5
# 4472  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 6949  20260206_142717  outer_iter_5                BH_MR_Exhaustion_6D_v5
# 4493  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 3489  20260205_033043  outer_iter_2  BH_CT_Uptrend_Volume_Pullback_15D_v2
# 4373  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 3424  20260205_033043  outer_iter_1         BH_CT_Uptrend_Pullback_10D_v1
# 950   20260201_061954  outer_iter_1              BH_MR_ShortTermDip_3D_v1
# 3491  20260205_033043  outer_iter_2  BH_CT_Uptrend_Volume_Pullback_15D_v2
# 4478  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 4490  20260205_093103  outer_iter_3            BH_MR_VolCompression_9D_v3
# 6588  20260206_142717  outer_iter_5                BH_MR_Exhaustion_6D_v5
# 3745  20260205_071052  outer_iter_1           BH_C_UptrendPullback_20D_v1
# 4731  20260206_002735          root                BH_MR_Exhaustion_5D_v1
# 6917  20260206_142717  outer_iter_5                BH_MR_Exhaustion_6D_v5
# 6192  20260206_142717  outer_iter_3                BH_MR_Exhaustion_5D_v3
# 3224  20260205_013521  outer_iter_1            TH_Uptrend_Pullback_10D_v1
#
#      backtest_mode  horizon_days         in_sample_period  \
# 4388   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 6600   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 7112   qlib_legacy           7.0  2015-01-01 ~ 2020-12-31
# 6880   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 4472   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 6949   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 4493   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 3489   qlib_native          15.0  2015-01-01 ~ 2020-12-31
# 4373   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 3424   qlib_native          10.0  2015-01-01 ~ 2020-12-31
# 950    qlib_native           3.0  2015-01-01 ~ 2020-12-31
# 3491   qlib_native          15.0  2015-01-01 ~ 2020-12-31
# 4478   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 4490   qlib_native           9.0  2015-01-01 ~ 2020-12-31
# 6588   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 3745   qlib_native          10.0  2015-01-01 ~ 2020-12-31
# 4731   qlib_native           5.0  2015-01-01 ~ 2020-12-31
# 6917   qlib_legacy           6.0  2015-01-01 ~ 2020-12-31
# 6192   qlib_legacy           5.0  2015-01-01 ~ 2020-12-31
# 3224   qlib_native          10.0  2015-01-01 ~ 2020-12-31
#
#             out_sample_period combo_idx       mode  threshold_q  ...  \
# 4388  2021-01-01 ~ 2025-12-31        30  fixed_q90         0.90  ...
# 6600  2021-01-01 ~ 2025-12-31        42     optuna          NaN  ...
# 7112  2021-01-01 ~ 2025-12-31         7     optuna          NaN  ...
# 6880  2021-01-01 ~ 2025-12-31       112     optuna          NaN  ...
# 4472  2021-01-01 ~ 2025-12-31        58  fixed_q90         0.90  ...
# 6949  2021-01-01 ~ 2025-12-31       129  fixed_q80         0.80  ...
# 4493  2021-01-01 ~ 2025-12-31        65  fixed_q90         0.90  ...
# 3489  2021-01-01 ~ 2025-12-31         4     optuna          NaN  ...
# 4373  2021-01-01 ~ 2025-12-31        25  fixed_q90         0.90  ...
# 3424  2021-01-01 ~ 2025-12-31        38  fixed_q80         0.80  ...
# 950   2021-01-01 ~ 2025-12-31         3  fixed_q80         0.80  ...
# 3491  2021-01-01 ~ 2025-12-31         4  fixed_q90         0.90  ...
# 4478  2021-01-01 ~ 2025-12-31        60  fixed_q90         0.90  ...
# 4490  2021-01-01 ~ 2025-12-31        64  fixed_q90         0.90  ...
# 6588  2021-01-01 ~ 2025-12-31        39     optuna          NaN  ...
# 3745  2021-01-01 ~ 2025-12-31         5  fixed_q80         0.80  ...
# 4731  2021-01-01 ~ 2025-12-31        13  fixed_q95         0.95  ...
# 6917  2021-01-01 ~ 2025-12-31       121  fixed_q80         0.80  ...
# 6192  2021-01-01 ~ 2025-12-31        75     optuna          NaN  ...
# 3224  2021-01-01 ~ 2025-12-31        42  fixed_q90         0.90  ...
#
#                    provider_uri benchmark_code enable_stage2 enable_stage3  \
# 4388  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 6600  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 7112  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 6880  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 4472  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 6949  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 4493  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 3489  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 4373  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 3424  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 950                         NaN            NaN           NaN           NaN
# 3491  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 4478  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 4490  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 6588  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 3745  ~/.qlib/qlib_data/cn_data       SH000905          None          None
# 4731  ~/.qlib/qlib_data/cn_data       SH000905         False          True
# 6917  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 6192  ~/.qlib/qlib_data/cn_data       SH000905          True          True
# 3224  ~/.qlib/qlib_data/cn_data       SH000905          None          None
#
#           mean       std annualized_return information_ratio  max_drawdown  \
# 4388  0.001375  0.022275          0.327144          0.951998     -0.571271
# 6600  0.001163  0.018888          0.276721          0.949681     -0.386825
# 7112  0.000997  0.017207          0.237334          0.894068     -0.347491
# 6880  0.001024  0.018122          0.243830          0.872137     -0.304664
# 4472  0.001010  0.018586          0.240428          0.838493     -0.439179
# 6949  0.001187  0.022146          0.282603          0.827177     -0.514403
# 4493  0.001086  0.020751          0.258520          0.807530     -0.379159
# 3489  0.001301  0.024976          0.309696          0.803762     -0.587617
# 4373  0.001138  0.022153          0.270783          0.792315     -0.583788
# 3424  0.000942  0.018711          0.224272          0.776929     -0.325594
# 950   0.000620  0.012330          0.147599          0.775968     -0.198011
# 3491  0.001104  0.023006          0.262764          0.740344     -0.396087
# 4478  0.000968  0.020599          0.230474          0.725243     -0.415840
# 4490  0.000855  0.018192          0.203497          0.725100     -0.463072
# 6588  0.000819  0.017576          0.194957          0.718996     -0.306899
# 3745  0.000764  0.016629          0.181719          0.708326     -0.369322
# 4731  0.000666  0.014780          0.158555          0.695360     -0.264654
# 6917  0.001024  0.022756          0.243808          0.694480     -0.557460
# 6192  0.000674  0.015580          0.160419          0.667401     -0.341573
# 3224  0.000839  0.019406          0.199721          0.667120     -0.465790
#
#       net_return
# 4388    2.928009
# 6600    2.299942
# 7112    1.803519
# 6880    1.838535
# 4472    1.765148
# 6949    2.142795
# 4493    1.881021
# 3489    2.327748
# 4373    1.959014
# 3424    1.533039
# 950     0.980118
# 3491    1.773146
# 4478    1.507777
# 4490    1.312401
# 6588    1.238495
# 3745    1.139421
# 4731    0.968205
# 6917    1.540014
# 6192    0.954390
# 3224    1.202577
#
# [20 rows x 24 columns]

# %%
df.sort_values(by='max_drawdown', ascending=False)
# Out:
#                run_id    outer_iter  \
# 4674  20260205_093220  outer_iter_4
# 950   20260201_061954  outer_iter_1
# 4677  20260205_093220  outer_iter_4
# 8114  20260207_051736  outer_iter_1
# 6348  20260206_142717  outer_iter_4
# ...               ...           ...
# 851   20260129_151128  outer_iter_1
# 852   20260129_151128  outer_iter_1
# 853   20260129_151128  outer_iter_1
# 854   20260129_151128  outer_iter_1
# 855   20260129_164059          root
#
#                                   hypothesis_id backtest_mode  horizon_days  \
# 4674  BH_Continuation_TrendPullback_20MA_15D_v1   qlib_native          15.0
# 950                    BH_MR_ShortTermDip_3D_v1   qlib_native           3.0
# 4677  BH_Continuation_TrendPullback_20MA_15D_v1   qlib_native          15.0
# 8114             BH_Continuation_Breakout_5D_v1   qlib_legacy           5.0
# 6348                     BH_MR_Exhaustion_4D_v4   qlib_legacy           4.0
# ...                                         ...           ...           ...
# 851                BH_SR_ShortTermRebound_2D_v1    vectorized           2.0
# 852                BH_SR_ShortTermRebound_2D_v1    vectorized           2.0
# 853                BH_SR_ShortTermRebound_2D_v1    vectorized           2.0
# 854                BH_SR_ShortTermRebound_2D_v1    vectorized           2.0
# 855                    BH_MR_PanicSelling_3D_v1   combined_or           NaN
#
#              in_sample_period        out_sample_period    combo_idx  \
# 4674  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31           10
# 950   2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31            3
# 4677  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31           11
# 8114  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31           51
# 6348  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31           10
# ...                       ...                      ...          ...
# 851   2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31            2
# 852   2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31            3
# 853   2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31            4
# 854   2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31            5
# 855                      None                     None  combined_or
#
#            mode  threshold_q  ...               provider_uri benchmark_code  \
# 4674     optuna          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 950   fixed_q80          0.8  ...                        NaN            NaN
# 4677     optuna          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8114     optuna          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 6348     optuna          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# ...         ...          ...  ...                        ...            ...
# 851      optuna          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 852      optuna          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 853      optuna          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 854      optuna          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 855      optuna          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
#
#      enable_stage2 enable_stage3      mean       std annualized_return  \
# 4674          None          None  0.000072  0.008222          0.017184
# 950            NaN           NaN  0.000620  0.012330          0.147599
# 4677          None          None  0.000106  0.008069          0.025258
# 8114          True          True  0.000587  0.013999          0.139739
# 6348          True          True  0.000557  0.013892          0.132661
# ...            ...           ...       ...       ...               ...
# 851           None          None       NaN       NaN               NaN
# 852           None          None       NaN       NaN               NaN
# 853           None          None       NaN       NaN               NaN
# 854           None          None       NaN       NaN               NaN
# 855           None          None       NaN       NaN               NaN
#
#      information_ratio  max_drawdown  net_return
# 4674          0.135471     -0.190487    0.047813
# 950           0.775968     -0.198011    0.980118
# 4677          0.202894     -0.204870    0.093307
# 8114          0.647039     -0.222351    0.809182
# 6348          0.618985     -0.239144    0.747962
# ...                ...           ...         ...
# 851                NaN           NaN         NaN
# 852                NaN           NaN         NaN
# 853                NaN           NaN         NaN
# 854                NaN           NaN         NaN
# 855                NaN           NaN         NaN
#
# [8828 rows x 24 columns]

# %%
# df.to_csv("/home/dgu/fin/01_15_new_qlib/paper/aggregated_stage4_results.csv", index=False)

# %%
df.sort_values('max_drawdown', ascending=False).head(12)#['information_ratio'].max()
# Out:
#                run_id    outer_iter  \
# 4674  20260205_093220  outer_iter_4
# 950   20260201_061954  outer_iter_1
# 4677  20260205_093220  outer_iter_4
# 8114  20260207_051736  outer_iter_1
# 6348  20260206_142717  outer_iter_4
# 6628  20260206_142717  outer_iter_5
# 7164  20260206_144300  outer_iter_2
# 4379  20260205_093103  outer_iter_3
# 7076  20260206_142717  outer_iter_5
# 7077  20260206_142717  outer_iter_5
# 6397  20260206_142717  outer_iter_4
# 4731  20260206_002735          root
#
#                                   hypothesis_id backtest_mode  horizon_days  \
# 4674  BH_Continuation_TrendPullback_20MA_15D_v1   qlib_native          15.0
# 950                    BH_MR_ShortTermDip_3D_v1   qlib_native           3.0
# 4677  BH_Continuation_TrendPullback_20MA_15D_v1   qlib_native          15.0
# 8114             BH_Continuation_Breakout_5D_v1   qlib_legacy           5.0
# 6348                     BH_MR_Exhaustion_4D_v4   qlib_legacy           4.0
# 6628                     BH_MR_Exhaustion_6D_v5   qlib_legacy           6.0
# 7164             BH_Continuation_Pullback_7D_v2   qlib_legacy           7.0
# 4379                 BH_MR_VolCompression_9D_v3   qlib_native           9.0
# 7076                     BH_MR_Exhaustion_6D_v5   qlib_legacy           6.0
# 7077                     BH_MR_Exhaustion_6D_v5   qlib_legacy           6.0
# 6397                     BH_MR_Exhaustion_4D_v4   qlib_legacy           4.0
# 4731                     BH_MR_Exhaustion_5D_v1   qlib_native           5.0
#
#              in_sample_period        out_sample_period combo_idx       mode  \
# 4674  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31        10     optuna
# 950   2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         3  fixed_q80
# 4677  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31        11     optuna
# 8114  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31        51     optuna
# 6348  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31        10     optuna
# 6628  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31        49     optuna
# 7164  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31        20     optuna
# 4379  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31        27  fixed_q90
# 7076  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31       161     optuna
# 7077  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31       161  fixed_q80
# 6397  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31        22  fixed_q80
# 4731  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31        13  fixed_q95
#
#       threshold_q  ...               provider_uri benchmark_code  \
# 4674          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 950          0.80  ...                        NaN            NaN
# 4677          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 8114          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 6348          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 6628          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 7164          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 4379         0.90  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 7076          NaN  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 7077         0.80  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 6397         0.80  ...  ~/.qlib/qlib_data/cn_data       SH000905
# 4731         0.95  ...  ~/.qlib/qlib_data/cn_data       SH000905
#
#      enable_stage2 enable_stage3      mean       std annualized_return  \
# 4674          None          None  0.000072  0.008222          0.017184
# 950            NaN           NaN  0.000620  0.012330          0.147599
# 4677          None          None  0.000106  0.008069          0.025258
# 8114          True          True  0.000587  0.013999          0.139739
# 6348          True          True  0.000557  0.013892          0.132661
# 6628          True          True  0.000595  0.015689          0.141514
# 7164          True          True  0.000420  0.020248          0.099932
# 4379          None          None  0.000459  0.014469          0.109242
# 7076          True          True  0.000086  0.018678          0.020477
# 7077          True          True  0.000075  0.018706          0.017852
# 6397          True          True  0.000175  0.015718          0.041626
# 4731         False          True  0.000666  0.014780          0.158555
#
#      information_ratio  max_drawdown  net_return
# 4674          0.135471     -0.190487    0.047813
# 950           0.775968     -0.198011    0.980118
# 4677          0.202894     -0.204870    0.093307
# 8114          0.647039     -0.222351    0.809182
# 6348          0.618985     -0.239144    0.747962
# 6628          0.584686     -0.239625    0.774567
# 7164          0.319911     -0.241505    0.296815
# 4379          0.489401     -0.250293    0.536981
# 7076          0.071061     -0.252904   -0.100916
# 7077          0.061860     -0.258231   -0.113539
# 6397          0.171666     -0.261085    0.066683
# 4731          0.695360     -0.264654    0.968205
#
# [12 rows x 24 columns]

# %%
df.query('run_id == "20260201_061954" & mode == "fixed_q80"')#.groupby('mode')['information_ratio'].max()
# Out:
#               run_id    outer_iter             hypothesis_id backtest_mode  \
# 950  20260201_061954  outer_iter_1  BH_MR_ShortTermDip_3D_v1   qlib_native
# 954  20260201_061954  outer_iter_1  BH_MR_ShortTermDip_3D_v1   qlib_native
# 962  20260201_061954  outer_iter_1  BH_MR_ShortTermDip_3D_v1   qlib_native
# 942  20260201_061954  outer_iter_1  BH_MR_ShortTermDip_3D_v1   qlib_native
# 946  20260201_061954  outer_iter_1  BH_MR_ShortTermDip_3D_v1   qlib_native
# 958  20260201_061954  outer_iter_1  BH_MR_ShortTermDip_3D_v1   qlib_native
#
#      horizon_days         in_sample_period        out_sample_period combo_idx  \
# 950           3.0  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         3
# 954           3.0  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         4
# 962           3.0  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         6
# 942           3.0  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         1
# 946           3.0  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         2
# 958           3.0  2015-01-01 ~ 2020-12-31  2021-01-01 ~ 2025-12-31         5
#
#           mode  threshold_q  ... provider_uri benchmark_code enable_stage2  \
# 950  fixed_q80          0.8  ...          NaN            NaN           NaN
# 954  fixed_q80          0.8  ...          NaN            NaN           NaN
# 962  fixed_q80          0.8  ...          NaN            NaN           NaN
# 942  fixed_q80          0.8  ...          NaN            NaN           NaN
# 946  fixed_q80          0.8  ...          NaN            NaN           NaN
# 958  fixed_q80          0.8  ...          NaN            NaN           NaN
#
#     enable_stage3      mean       std annualized_return information_ratio  \
# 950           NaN  0.000620  0.012330          0.147599          0.775968
# 954           NaN  0.000199  0.015630          0.047370          0.196453
# 962           NaN  0.000100  0.010842          0.023772          0.142121
# 942           NaN -0.000131  0.015380         -0.031220         -0.131581
# 946           NaN -0.000454  0.014644         -0.108068         -0.478338
# 958           NaN -0.000634  0.015754         -0.150943         -0.621043
#
#      max_drawdown  net_return
# 950     -0.198011    0.980118
# 954     -0.395830    0.099581
# 962     -0.445245    0.052966
# 942     -0.670982   -0.271762
# 946     -1.088484   -0.505929
# 958     -1.207766   -0.613594
#
# [6 rows x 24 columns]

# %%
df.query('run_id == "20260208_020327"').sort_values(by='information_ratio', ascending=False)#.head(20)
# Out:
# Empty DataFrame
# Columns: [run_id, outer_iter, hypothesis_id, backtest_mode, horizon_days, in_sample_period, out_sample_period, combo_idx, mode, threshold_q, optimal_thresholds, universe, region, qlib_market, provider_uri, benchmark_code, enable_stage2, enable_stage3, mean, std, annualized_return, information_ratio, max_drawdown, net_return]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.query('run_id == "20260206_142717"').groupby(['mode'])[['information_ratio', 'max_drawdown']].mean().dropna()
# Out:
#            information_ratio  max_drawdown
# mode
# fixed_q80          -0.211479     -0.647722
# fixed_q90          -0.238512     -0.631802
# fixed_q95          -0.272793     -0.631446
# optuna             -0.229225     -0.702740

# %%
df.query('run_id == "20260206_142717"')['information_ratio'].mean()#.sort_values(by='information_ratio', ascending=False)#.query('threshold_q == 0.9')#.values[-2]
# Out:
# np.float64(-0.23800228092980621)

# %%
df['horizon_days'].value_counts()
# Out:
# horizon_days
# 5.0     2856
# 3.0     1748
# 7.0     1120
# 6.0     1082
# 10.0     680
# 8.0      316
# 2.0      254
# 9.0      221
# 12.0     192
# 4.0      130
# 21.0     117
# 15.0      90
# Name: count, dtype: int64

# %%
df.query('run_id == "20260202_125915" and combo_idx == 12').groupby(['run_id', 'mode', 'outer_iter', 'combo_idx'])['information_ratio'].max().sort_values(ascending=False).reset_index()
# Out:
#              run_id       mode    outer_iter  combo_idx  information_ratio
# 0   20260202_125915     optuna  outer_iter_5         12           0.547626
# 1   20260202_125915  fixed_q90  outer_iter_3         12          -0.103851
# 2   20260202_125915  fixed_q95  outer_iter_3         12          -0.138750
# 3   20260202_125915  fixed_q90  outer_iter_4         12          -0.251508
# 4   20260202_125915  fixed_q95  outer_iter_5         12          -0.251508
# 5   20260202_125915  fixed_q95  outer_iter_1         12          -0.251508
# 6   20260202_125915  fixed_q95  outer_iter_4         12          -0.251508
# 7   20260202_125915  fixed_q90  outer_iter_5         12          -0.264892
# 8   20260202_125915  fixed_q90  outer_iter_1         12          -0.276407
# 9   20260202_125915     optuna  outer_iter_4         12          -0.314707
# 10  20260202_125915     optuna  outer_iter_3         12          -0.602444
# 11  20260202_125915     optuna  outer_iter_1         12          -1.323606

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

# IC 대체로 가장 무난한 건 (OOS) excess_return_with_cost의 information_ratio 입니다.
# - IC처럼 scale-free (risk-adjusted)라서 round 간 비교가 쉽고
# - transaction cost를 포함할 수 있어 실제 운용 관점에 더 가깝습니다.

METRIC = "information_ratio"  # 예: annualized_return, net_return, max_drawdown
MODE = "optuna"              # optuna / fixed_q90 / fixed_q95 / None(전체)
GROUP_COL = None             # 예: "hypothesis_id" 또는 사용자 정의 그룹 컬럼

df_plot = df.copy()
if MODE is not None:
    df_plot = df_plot[df_plot["mode"] == MODE]

# outer_iter_1..N 에서 N만 뽑아 Round로 사용
df_plot["round"] = pd.to_numeric(
    df_plot["outer_iter"].astype(str).str.extract(r"(\d+)")[0],
    errors="coerce",
)
print('rows after MODE filter:', len(df_plot))
if len(df_plot) > 0:
    print('mode counts (top):', df_plot['mode'].value_counts().head(5).to_dict())
    print('outer_iter sample:', df_plot['outer_iter'].astype(str).dropna().unique()[:5])
df_plot = df_plot.dropna(subset=["round", METRIC]).copy()
print(f'rows after dropna(round,{METRIC}):', len(df_plot))
df_plot["round"] = df_plot["round"].astype(int)

# round별로 여러 combo가 있으면, run(및 group) 단위에서 best(metric 최대)로 대표값을 잡는 게 보통 제일 직관적
keys = ["run_id", "round"]
if GROUP_COL is not None:
    keys = [GROUP_COL, *keys]

df_best = df_plot.groupby(keys, as_index=False)[METRIC].max()
if df_best.empty:
    print('df_best is empty -> 대부분 round 추출 실패 or metric이 전부 NaN 입니다.')
    print('확인 1) outer_iter에서 숫자 뽑는 정규식은 str.extract(r"(\\d+)") 처럼 \\d(한 번) 패턴이어야 합니다.')
    print('확인 2) MODE 값:', MODE, ' / df_plot.mode unique(top):', df_plot['mode'].value_counts().head(10).to_dict() if 'mode' in df_plot else None)
    print('확인 3) METRIC 값:', METRIC, ' / non-null:', int(df_plot[METRIC].notna().sum()) if METRIC in df_plot else None)
    cols = [c for c in ['run_id','outer_iter','round','mode',METRIC] if c in df_plot.columns]
    print(df_plot[cols].head(20).to_string(index=False))
    raise ValueError('df_best is empty (see debug prints above)')

plt.figure(figsize=(7, 4))

if GROUP_COL is None:
    agg = df_best.groupby("round")[METRIC].agg(["mean", "std", "count"]).reset_index()
    half_std = 0.5 * agg["std"].fillna(0.0)
    plt.plot(agg["round"], agg["mean"], marker="o", label=f"Mean ({MODE})")
    plt.fill_between(
        agg["round"],
        agg["mean"] - half_std,
        agg["mean"] + half_std,
        alpha=0.25,
        label="±1/2 Std. Dev.",
    )
else:
    for group_value, sub in df_best.groupby(GROUP_COL):
        agg = sub.groupby("round")[METRIC].agg(["mean", "std", "count"]).reset_index()
        half_std = 0.5 * agg["std"].fillna(0.0)
        plt.plot(agg["round"], agg["mean"], marker="o", label=f"{group_value} Mean")
        plt.fill_between(
            agg["round"],
            agg["mean"] - half_std,
            agg["mean"] + half_std,
            alpha=0.18,
        )

plt.xticks(sorted(df_best["round"].unique()))
plt.xlabel("Round")
plt.ylabel(METRIC)
plt.title(f"Evolution of {METRIC} by round")
plt.legend(loc="best")
plt.tight_layout()
plt.show()

# 참고용 테이블
df_best.sort_values([*([] if GROUP_COL is None else [GROUP_COL]), "round"]).head(20)
# Out:
# rows after MODE filter: 2802
# mode counts (top): {'optuna': 2802}
# outer_iter sample: ['outer_iter_5' 'outer_iter_2' 'outer_iter_3' 'outer_iter_1'
#  'outer_iter_4']
# rows after dropna(round,information_ratio): 2441
#              run_id  round  information_ratio
# 0   20260129_183158      1          -0.776955
# 1   20260129_183941      1          -1.109860
# 2   20260129_185221      1          -0.514828
# 3   20260129_191343      1          -1.134011
# 15  20260130_141853      1          -0.104748
# 10  20260129_201801      1          -0.322511
# 29  20260202_061256      1          -0.272442
# 28  20260202_010919      1          -0.568662
# 24  20260201_122716      1           0.046833
# 25  20260201_130021      1          -0.251508
# 23  20260201_111256      1          -0.344781
# 22  20260201_094610      1           0.065302
# 20  20260201_082914      1          -0.438662
# 21  20260201_084203      1           0.266454
# 18  20260130_193051      1          -1.336830
# 19  20260201_061954      1           0.281440
# 30  20260202_061321      1          -0.018940
# 27  20260201_232215      1           0.157184
# 26  20260201_225023      1          -0.875914
# 55  20260204_022915      1          -0.251508

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

# IC 대체로 가장 무난한 건 (OOS) excess_return_with_cost의 information_ratio 입니다.
# - IC처럼 scale-free (risk-adjusted)라서 round 간 비교가 쉽고
# - transaction cost를 포함할 수 있어 실제 운용 관점에 더 가깝습니다.

METRIC = "information_ratio"  # 예: annualized_return, net_return, max_drawdown
MODE = "optuna"              # optuna / fixed_q90 / fixed_q95 / None(전체)
GROUP_COL = None             # 예: "hypothesis_id" 또는 사용자 정의 그룹 컬럼

df_plot = df.copy()
if MODE is not None:
    df_plot = df_plot[df_plot["mode"] == MODE]

# outer_iter_1..N 에서 N만 뽑아 Round로 사용
df_plot["round"] = pd.to_numeric(
    df_plot["outer_iter"].astype(str).str.extract(r"(\d+)")[0],
    errors="coerce",
)
print('rows after MODE filter:', len(df_plot))
if len(df_plot) > 0:
    print('mode counts (top):', df_plot['mode'].value_counts().head(5).to_dict())
    print('outer_iter sample:', df_plot['outer_iter'].astype(str).dropna().unique()[:5])
df_plot = df_plot.dropna(subset=["round", METRIC]).copy()
print(f'rows after dropna(round,{METRIC}):', len(df_plot))
df_plot["round"] = df_plot["round"].astype(int)

# round별로 여러 combo가 있으면, run(및 group) 단위에서 best(metric 최대)로 대표값을 잡는 게 보통 제일 직관적
keys = ["run_id", "round"]
if GROUP_COL is not None:
    keys = [GROUP_COL, *keys]

df_best = df_plot.groupby(keys, as_index=False)[METRIC].max()
if df_best.empty:
    print('df_best is empty -> 대부분 round 추출 실패 or metric이 전부 NaN 입니다.')
    print('확인 1) outer_iter에서 숫자 뽑는 정규식은 str.extract(r"(\\d+)") 처럼 \\d(한 번) 패턴이어야 합니다.')
    print('확인 2) MODE 값:', MODE, ' / df_plot.mode unique(top):', df_plot['mode'].value_counts().head(10).to_dict() if 'mode' in df_plot else None)
    print('확인 3) METRIC 값:', METRIC, ' / non-null:', int(df_plot[METRIC].notna().sum()) if METRIC in df_plot else None)
    cols = [c for c in ['run_id','outer_iter','round','mode',METRIC] if c in df_plot.columns]
    print(df_plot[cols].head(20).to_string(index=False))
    raise ValueError('df_best is empty (see debug prints above)')

plt.figure(figsize=(7, 4))

if GROUP_COL is None:
    agg = df_best.groupby("round")[METRIC].agg(["mean", "std", "count"]).reset_index()
    half_std = 0.5 * agg["std"].fillna(0.0)
    plt.plot(agg["round"], agg["mean"], marker="o", label=f"Mean ({MODE})")
    plt.fill_between(
        agg["round"],
        agg["mean"] - half_std,
        agg["mean"] + half_std,
        alpha=0.25,
        label="±1/2 Std. Dev.",
    )
else:
    for group_value, sub in df_best.groupby(GROUP_COL):
        agg = sub.groupby("round")[METRIC].agg(["mean", "std", "count"]).reset_index()
        half_std = 0.5 * agg["std"].fillna(0.0)
        plt.plot(agg["round"], agg["mean"], marker="o", label=f"{group_value} Mean")
        plt.fill_between(
            agg["round"],
            agg["mean"] - half_std,
            agg["mean"] + half_std,
            alpha=0.18,
        )

plt.xticks(sorted(df_best["round"].unique()))
plt.xlabel("Round")
plt.ylabel(METRIC)
plt.title(f"Evolution of {METRIC} by round")
plt.legend(loc="best")
plt.tight_layout()
plt.show()

# 참고용 테이블
df_best.sort_values([*([] if GROUP_COL is None else [GROUP_COL]), "round"]).head(20)
# Out:
# rows after MODE filter: 2802
# mode counts (top): {'optuna': 2802}
# outer_iter sample: ['outer_iter_5' 'outer_iter_2' 'outer_iter_3' 'outer_iter_1'
#  'outer_iter_4']
# rows after dropna(round,information_ratio): 2441
#              run_id  round  information_ratio
# 0   20260129_183158      1          -0.776955
# 1   20260129_183941      1          -1.109860
# 2   20260129_185221      1          -0.514828
# 3   20260129_191343      1          -1.134011
# 15  20260130_141853      1          -0.104748
# 10  20260129_201801      1          -0.322511
# 29  20260202_061256      1          -0.272442
# 28  20260202_010919      1          -0.568662
# 24  20260201_122716      1           0.046833
# 25  20260201_130021      1          -0.251508
# 23  20260201_111256      1          -0.344781
# 22  20260201_094610      1           0.065302
# 20  20260201_082914      1          -0.438662
# 21  20260201_084203      1           0.266454
# 18  20260130_193051      1          -1.336830
# 19  20260201_061954      1           0.281440
# 30  20260202_061321      1          -0.018940
# 27  20260201_232215      1           0.157184
# 26  20260201_225023      1          -0.875914
# 55  20260204_022915      1          -0.251508

# %%
# Legacy IR plot (ours + optional baselines)
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json
from pathlib import Path

sns.set_theme(style="whitegrid")

# ------------------- settings -------------------
ONE_RUN = "20260206_142717"  # outer_iter_1~N 있는 run_id
METRIC = "information_ratio"  # 보통 IR을 보기 좋음
MODE = "optuna"               # optuna / fixed_q90 / fixed_q95

# 어떤 통계를 그릴지: mean / max
PLOT_STAT = "best"  # "mean" | "max" | "best" (higher of mean/max per round)
PLOT_RDAGENT = False
PLOT_ALPHAAGENT = False

# R&D-Agent / AlphaForge : metrics_timeseries.csv 기반 loop별 IR 재계산
RDAGENT_METRICS_TS = Path("/home/dgu/fin/01_15_new_qlib copy/metrics_timeseries.csv")
AUTO_SELECT_BASELINE_FILES = True
MIN_BASELINE_ROUNDS = 5

# AlphaAgent : AlphaAgent/log/*/metrics.csv 기반 loop별 IR
# - 지정 안 하면 가장 최신 metrics.csv를 자동 선택
ALPHAAGENT_METRICS_CSV = None

# baseline loop index를 1부터 보이게 정규화할지
NORMALIZE_BASELINE_LOOP_TO_1 = True
REQUIRE_BASELINE_FULL_LOOPS = True  # ours rounds와 동일 개수/셋일 때만 baseline 표시

TRADING_DAYS = 252

# save options
SAVE_PDF = True
PDF_PATH = Path("/home/dgu/fin/01_15_new_qlib/analysis/ir_plot.pdf")


def _annualized_ir(daily_excess: pd.Series, trading_days: int = 252) -> float:
    daily_excess = daily_excess.astype(float).dropna()
    if len(daily_excess) == 0:
        return float("nan")
    mean = float(daily_excess.mean())
    std = float(daily_excess.std(ddof=0))
    if std <= 0:
        return float("nan")
    return float(mean / std * (trading_days ** 0.5))


def _count_rounds_from_metrics_ts(p: Path) -> int:
    try:
        df = pd.read_csv(p, usecols=["loop"])
        return int(df["loop"].nunique())
    except Exception:
        return 0


def _count_rounds_from_alphaagent_metrics(p: Path) -> int:
    try:
        df = pd.read_csv(p, usecols=["loop"])
        return int(df["loop"].nunique())
    except Exception:
        return 0


def _latest_metrics_timeseries_csv(min_rounds: int = 5) -> Path | None:
    # search common locations for metrics_timeseries.csv
    cands = []
    roots = [
        Path("/home/dgu/fin/01_15_new_qlib copy"),
        Path("/home/dgu/fin/others/02_agent/AlphaForge"),
    ]
    for root in roots:
        if not root.exists():
            continue
        for p in root.rglob("metrics_timeseries.csv"):
            n = _count_rounds_from_metrics_ts(p)
            if n >= min_rounds:
                cands.append((p.stat().st_mtime, p))
    if not cands:
        return None
    cands.sort(reverse=True)
    return cands[0][1]


def _load_rdagent_loop_metrics(ts_path: Path) -> pd.DataFrame:
    df_ts = pd.read_csv(ts_path)
    df_ts["date"] = pd.to_datetime(df_ts["date"])
    df_ts = df_ts.sort_values(["loop", "date"]).copy()

    cum_col = "Cumulative Excess Return (With Cost)"
    if cum_col not in df_ts.columns:
        raise ValueError(f"missing column: {cum_col} in {ts_path}")

    rows = []
    for loop, g in df_ts.groupby("loop"):
        g = g.sort_values("date")
        cum = g[cum_col].astype(float)
        daily = cum.diff().fillna(cum.iloc[0])
        rows.append(
            {
                "loop": int(loop),
                "IR": _annualized_ir(daily, TRADING_DAYS),
                "CR_excess_end": float(cum.iloc[-1]),
                "end_date": g["date"].iloc[-1].date().isoformat(),
            }
        )

    out = pd.DataFrame(rows).sort_values("loop")
    return out


def _latest_alphaagent_metrics_csv(min_rounds: int = 5) -> Path | None:
    root = Path("/home/dgu/fin/AlphaAgent/log")
    if not root.exists():
        return None
    cands = []
    for p in root.glob("*/metrics.csv"):
        n = _count_rounds_from_alphaagent_metrics(p)
        if n >= min_rounds:
            cands.append((p.stat().st_mtime, p))
    if not cands:
        return None
    cands.sort(reverse=True)
    return cands[0][1]


def _load_alphaagent_loop_metrics(metrics_csv: Path) -> pd.DataFrame:
    df_m = pd.read_csv(metrics_csv)
    if "section" in df_m.columns:
        df_m = df_m[df_m["section"] == "with_cost"].copy()

    # loop별로 마지막(최신) row를 사용
    df_m = df_m.sort_values(["loop", "timestamp"]).copy()
    last = df_m.groupby("loop", as_index=False).tail(1)

    out = last[["loop", "Information Ratio", "Cumulative Return", "Max Drawdown", "timestamp"]].copy()
    out = out.rename(
        columns={
            "Information Ratio": "IR",
            "Cumulative Return": "CR_end",
            "Max Drawdown": "MDD",
            "timestamp": "ts",
        }
    )
    out["loop"] = out["loop"].astype(int)
    return out.sort_values("loop")


def _norm_loop(loop_s: pd.Series) -> pd.Series:
    loop_s = loop_s.astype(int)
    if not NORMALIZE_BASELINE_LOOP_TO_1:
        return loop_s
    return loop_s - int(loop_s.min()) + 1


def _maybe_filter_baseline(df_base: pd.DataFrame | None, ours_rounds: list[int]) -> pd.DataFrame | None:
    if df_base is None or len(df_base) == 0:
        return df_base
    if not REQUIRE_BASELINE_FULL_LOOPS:
        return df_base
    base_rounds = sorted(set(int(x) for x in _norm_loop(df_base["loop"]).unique()))
    ours_rounds = sorted(set(int(x) for x in ours_rounds))
    if base_rounds != ours_rounds:
        print(f"skip baseline: rounds mismatch base={base_rounds} ours={ours_rounds}")
        return None
    return df_base


# ------------------- ours: round별 IR -------------------
df_run = df[(df["run_id"] == ONE_RUN) & (df["mode"] == MODE)].copy()
df_run["round"] = pd.to_numeric(
    df_run["outer_iter"].astype(str).str.extract(r"(\d+)")[0],
    errors="coerce",
)
df_run = df_run.dropna(subset=["round", METRIC]).copy()
df_run["round"] = df_run["round"].astype(int)

if df_run.empty:
    raise ValueError(f"No rows for run_id={ONE_RUN}, mode={MODE}, metric={METRIC}")

agg = (
    df_run.groupby("round")[METRIC]
    .agg(["mean", "std", "count", "max"])
    .reset_index()
    .sort_values("round")
)

half_std = 0.5 * agg["std"].fillna(0.0)

# ------------------- baselines: loop별 IR -------------------
rd_tbl = None
rd_csv = RDAGENT_METRICS_TS
if AUTO_SELECT_BASELINE_FILES:
    rd_csv = _latest_metrics_timeseries_csv(MIN_BASELINE_ROUNDS) or RDAGENT_METRICS_TS
if rd_csv is not None and Path(rd_csv).exists():
    rd_tbl = _load_rdagent_loop_metrics(Path(rd_csv))

alphaagent_csv = ALPHAAGENT_METRICS_CSV
if AUTO_SELECT_BASELINE_FILES:
    alphaagent_csv = _latest_alphaagent_metrics_csv(MIN_BASELINE_ROUNDS) or alphaagent_csv
elif alphaagent_csv is None:
    alphaagent_csv = _latest_alphaagent_metrics_csv(MIN_BASELINE_ROUNDS)

aa_tbl = None
if alphaagent_csv is not None and Path(alphaagent_csv).exists():
    aa_tbl = _load_alphaagent_loop_metrics(Path(alphaagent_csv))

# baseline loop count check
ours_rounds = list(agg["round"])
rd_tbl = _maybe_filter_baseline(rd_tbl, ours_rounds)
aa_tbl = _maybe_filter_baseline(aa_tbl, ours_rounds)


# ------------------- plot -------------------
plt.figure(figsize=(5.2, 4.2))

if PLOT_STAT == "mean":
    y = agg["mean"]
    label = "Ours (mean IR)"
elif PLOT_STAT == "max":
    y = agg["max"]
    label = "Ours (max IR)"
elif PLOT_STAT == "best":
    y = np.maximum(agg["mean"], agg["max"])
    label = "Ours (best IR)"
else:
    raise ValueError(f"Unknown PLOT_STAT: {PLOT_STAT}")

plt.plot(
    agg["round"],
    y,
    marker="o",
    markersize=12,
    linewidth=4,
    label=label,
)

plt.fill_between(
    agg["round"],
    y - half_std,
    y + half_std,
    alpha=0.18,
    label="Ours (±1/2 std)",
)

if PLOT_RDAGENT and rd_tbl is not None and len(rd_tbl) > 0:
    x = _norm_loop(rd_tbl["loop"])
    plt.plot(x, rd_tbl["IR"], marker="s", markersize=7, linewidth=3, label="R&D-Agent/AlphaForge (IR)")

if PLOT_ALPHAAGENT and aa_tbl is not None and len(aa_tbl) > 0:
    x = _norm_loop(aa_tbl["loop"])
    plt.plot(x, aa_tbl["IR"], marker="^", markersize=7, linewidth=3, label="AlphaAgent (IR)")

plt.xlabel("Loop", fontsize=16)
plt.ylabel("IR", fontsize=16)
plt.tick_params(axis="both", which="major", labelsize=16)

plt.xticks(sorted(set(int(x) for x in agg["round"].unique())))
plt.grid(True, alpha=0.25)
plt.legend(
    loc="best",
    fontsize=14,
    frameon=True,        # 박스 ON
    facecolor="white",   # 흰 배경
    framealpha=1.0       # 완전 불투명
)

plt.tight_layout()
if SAVE_PDF:
    PDF_PATH.parent.mkdir(parents=True, exist_ok=True)
    plt.savefig(PDF_PATH, format="pdf", bbox_inches="tight")
plt.show()

# ------------------- tables -------------------
print('Ours:')
display(agg)

if PLOT_RDAGENT and rd_tbl is not None:
    print('R&D-Agent/AlphaForge (from metrics_timeseries.csv):')
    display(rd_tbl)

if PLOT_ALPHAAGENT and aa_tbl is not None:
    print(f'AlphaAgent (from {alphaagent_csv}):')
    display(aa_tbl)
# Out:
# skip baseline: rounds mismatch base=[1, 2, 3] ours=[1, 2, 3, 4, 5]
# Ours:
#    round      mean       std  count       max
# 0      1 -0.536874  0.475244     33  0.419702
# 1      2 -0.257517  0.284463     48  0.393039
# 2      3 -0.283746  0.347067    104  0.667401
# 3      4 -0.174194  0.342312     31  0.622314
# 4      5 -0.134288  0.342467    163  0.949681

# %%
# Multi-line cumulative excess return plot (AlphaForge / R&D-Agent / AlphaAgent)

from __future__ import annotations

import sys
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt


def _safe_read_pickle(p):
    """pd.read_pickle wrapper that tolerates NumPy 2.x pickles (numpy._core) in NumPy 1.x envs."""
    try:
        return pd.read_pickle(p)
    except ModuleNotFoundError as e:
        if "numpy._core" not in str(e):
            raise
        import numpy.core as npcore

        sys.modules.setdefault("numpy._core", npcore)
        try:
            import numpy.core._multiarray_umath as mau

            sys.modules.setdefault("numpy._core._multiarray_umath", mau)
        except Exception:
            pass
        return pd.read_pickle(p)


# --- project root 찾기 (run.cumulative_return import용) ---
CWD = Path.cwd().resolve()
if CWD.name == "analysis" and (CWD / "0203 copy 2.ipynb").exists():
    PROJECT_ROOT = CWD.parent
else:
    PROJECT_ROOT = None
    cur = CWD
    for _ in range(6):
        if (cur / "run").is_dir() and (cur / "runs").is_dir():
            PROJECT_ROOT = cur
            break
        cur = cur.parent
    if PROJECT_ROOT is None:
        PROJECT_ROOT = CWD

sys.path.insert(0, str(PROJECT_ROOT))
from run.cumulative_return import _compute_curves  # noqa: E402


PLOT_KIND = "excess_with_cost"  # "excess_with_cost" | "excess_without_cost"
CUM_METHOD = "qlib_cumsum"      # "qlib_cumsum" | "compound"

LABEL_TO_PKL: dict[str, str] = {
    "AlphaForge": "/home/dgu/fin/01_15_new_qlib copy/2026-02-03_06-31-06-947364.pkl",
    "R&D-Agent": "/home/dgu/fin/01_15_new_qlib copy/2026-02-03_06-31-06-947364.pkl",
    "AlphaAgent": "/home/dgu/fin/AlphaAgent/results/2026-02-03_17-23-06-199838/backtest/1711570d9efb4e6191ec765dffc93c86/ret.pkl",
    "Ours": "/home/dgu/fin/01_15_new_qlib/runs/20260206_142717/qlib_artifacts/iter_4/combo_10/oos/report_normal_1day.pkl",
}

# 원하는 라벨만 선택해서 그리기
PLOT_LABELS = ["AlphaForge", "R&D-Agent", "AlphaAgent"]  # + ["Ours"]
label_to_pkl = {k: v for k, v in LABEL_TO_PKL.items() if k in set(PLOT_LABELS)}
if not label_to_pkl:
    raise ValueError("No labels selected. Check PLOT_LABELS / LABEL_TO_PKL")


def _daily_excess_series_from_pkl(pkl_path: str, plot_kind: str) -> pd.Series:
    df = _safe_read_pickle(pkl_path)
    curves = _compute_curves(df)

    bench = curves["bench"] if "bench" in curves.columns else 0.0

    if plot_kind == "excess_with_cost":
        daily = curves["net"] - bench
    elif plot_kind == "excess_without_cost":
        daily = curves["gross"] - bench
    else:
        raise ValueError(f"Unknown plot_kind: {plot_kind}")

    daily = daily.astype(float).fillna(0.0)
    daily.name = Path(pkl_path).parent.name
    return daily


def _cumulate(daily: pd.Series, method: str) -> pd.Series:
    if method == "qlib_cumsum":
        return daily.cumsum()
    if method == "compound":
        return (1.0 + daily).cumprod() - 1.0
    raise ValueError(f"Unknown method: {method}")


series = {
    label: _cumulate(_daily_excess_series_from_pkl(pkl_path, PLOT_KIND), CUM_METHOD)
    for label, pkl_path in label_to_pkl.items()
}

curve_df_raw = pd.concat(series, axis=1).sort_index()
curve_df = curve_df_raw.ffill()

fig, ax = plt.subplots(figsize=(12, 5))
ax.plot(curve_df.index, [0.0] * len(curve_df), "--", color="#8c564b", linewidth=2, label="Benchmark (0 in excess space)")
for col in curve_df.columns:
    ax.plot(curve_df.index, curve_df[col], linewidth=2, label=col)

ax.set_ylabel("Cumulative Excess Return")
ax.grid(True, alpha=0.3)
ax.legend(loc="upper left", fontsize=9, frameon=False)
fig.autofmt_xdate()
plt.show()


# end-point table (각 라인별 마지막 유효값 기준)
last_valid = curve_df_raw.apply(lambda s: s.dropna().iloc[-1] if s.notna().any() else float("nan"))
last_date = curve_df_raw.apply(lambda s: s.dropna().index[-1].date().isoformat() if s.notna().any() else None)
end_table = (
    pd.DataFrame({"last_date": last_date, "end_value": last_valid})
    .sort_values("end_value", ascending=False)
)
end_table
# Out:
#              last_date  end_value
# AlphaForge  2025-12-29   0.231744
# R&D-Agent   2025-12-29   0.231744
# AlphaAgent  2025-12-26   0.056409
